# %%
import pandas as pd

# %%
abp_data = pd.read_csv('example_abp_data.csv')
input_data = pd.read_csv('example_input_data.csv')

# %%
print(abp_data.info(), input_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2764 entries, 0 to 2763
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SINGLE_LINE_ADDRESS  2764 non-null   object
#  1   POSTCODE             2764 non-null   object
#  2   STREET_NAME          2520 non-null   object
# dtypes: object(3)
# memory usage: 64.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Address_Line_1  100 non-null    object
#  1   Address_Line_2  90 non-null     object
#  2   Address_Line_3  83 non-null     object
#  3   Address_Line_4  45 non-null     object
#  4   Address_Line_5  14 non-null     object
#  5   Postcode        100 non-null    object
# dtypes: object(6)
# memory usage: 4.8+ KB
# None None

# %%
abp_data.head()
# Out:
#                                  SINGLE_LINE_ADDRESS POSTCODE    STREET_NAME
# 0  PACEC, SECOND FLOOR, 49-53 REGENT STREET, CAMB...  CB2 1AB  REGENT STREET
# 1  FIRST FLOOR, 47-53 REGENT STREET, CAMBRIDGE, C...  CB2 1AB  REGENT STREET
# 2  BUBBLE LTD, SUITE 1, RAVENSCROFT HOUSE, 59-61 ...  CB2 1AB  REGENT STREET
# 3  EDE & RAVENSCROFT, SUITE 2, RAVENSCROFT HOUSE,...  CB2 1AB  REGENT STREET
# 4  CAMBRIDGE NUTRACEUTICALS LTD, SUITE 3, RAVENSC...  CB2 1AB  REGENT STREET

# %%
input_data.head()
# Out:
#                      Address_Line_1         Address_Line_2  \
# 0                            UNIT 3  39-41 MOORBRIDGE ROAD
# 1                        4 WORKSHOP             PERCY ROAD
# 2                       SAXON HOUSE             HENSON WAY
# 3                     1 QUARRY ROAD            NORTHAMPTON
# 4  METER R/O UNIT 54 UNKNOWN SUPPLY            DALTON PARK
#
#                   Address_Line_3 Address_Line_4 Address_Line_5  Postcode
# 0                     MAIDENHEAD      BERKSHIRE            NaN   SL6 8LT
# 1                     DARLINGTON            NaN            NaN   DL3 0RX
# 2  TELFORD WAY INDUSTRIAL ESTATE      KETTERING       NN16 8PX  NN16 8PX
# 3                        NN5 6NT            NaN            NaN   NN5 6NT
# 4                         MURTON         SEAHAM            NaN   SR7 9HU

# %%
def check_address(postcode, address_lines, abp_data):
    """
    Check if any of the address lines appear in the STREET_NAME or SINGLE_LINE_ADDRESS columns of abp_data for a given postcode.

    Parameters:
    postcode (str): The postcode to match in the abp_data DataFrame.
    address_lines (list): A list of address lines to check against the STREET_NAME and SINGLE_LINE_ADDRESS columns.
    abp_data (DataFrame): The DataFrame containing SINGLE_LINE_ADDRESS, POSTCODE, and STREET_NAME columns.

    Returns:
    str: 'Yes' if any address line appears in STREET_NAME for the same postcode, 'No' otherwise.
    """
    matching_rows = abp_data[abp_data['POSTCODE'] == postcode]
    for _, row in matching_rows.iterrows():
        street_name = row['STREET_NAME']
        full_address = row['SINGLE_LINE_ADDRESS']
        if pd.notna(street_name):  # Check if street_name is not NaN
            for line in address_lines:
                if (line.upper() in street_name.upper()) or (line.upper() in full_address.upper()): # Return 'Yes' if in either STREET_NAME or SINGLE_LINE_ADDRESS
                    return 'Yes'
        # If STREET_NAME is NaN but correct address is in SINGLE_LINE_ADDRESS return 'Yes'
        elif pd.isna(street_name):
            for line in address_lines:
                if line.upper() in full_address.upper():
                    return 'Yes'
    return 'No'

def create_street_in_postcode_col(input_data, abp_data):
    """
    Update the input_data DataFrame with a 'Street_In_Postcode' column indicating if any address lines appear in STREET_NAME or SINGLE_LINE_ADDRESS for the same postcode.

    Parameters:
    input_data (DataFrame): The DataFrame containing address lines and postcodes.
    abp_data (DataFrame): The DataFrame containing SINGLE_LINE_ADDRESS, POSTCODE, and STREET_NAME columns.

    Returns:
    DataFrame: The updated input_data DataFrame with the 'Street_In_Postcode' column.
    """
    input_data['Street_In_Postcode'] = input_data.apply(
        lambda row: check_address(
            row['Postcode'],
            [str(line) if pd.notna(line) else '' for line in [
            row['Address_Line_1'], row['Address_Line_2'], row['Address_Line_3'], row['Address_Line_4'], row['Address_Line_5']
        ]],
            abp_data
        ),
        axis=1
    )
    return input_data

# %% [markdown]
# Only issue with this implementation is that if only the town appears in the full address, then we return yes.
#
# Also not sure if they want me to check just the STREET_NAME column or also the SINGLE_ADDRESS_LINE column.

# %%
input_data = create_street_in_postcode_col(input_data, abp_data)

# %%
input_data.head(60)
# Out:
#                        Address_Line_1           Address_Line_2  \
# 0                              UNIT 3    39-41 MOORBRIDGE ROAD
# 1                          4 WORKSHOP               PERCY ROAD
# 2                         SAXON HOUSE               HENSON WAY
# 3                       1 QUARRY ROAD              NORTHAMPTON
# 4    METER R/O UNIT 54 UNKNOWN SUPPLY              DALTON PARK
# 5                             UNIT 17            MAITLAND ROAD
# 6          NORTH MALTING THE MALTINGS             FELAW STREET
# 7                 19-21 REGENT STREET                      NaN
# 8              UNIT 3 RIVERSIDE HOUSE   24 LOWER SOUTHEND ROAD
# 9                WORKSHOP JOHNS AUTOS         TEMPERANCE PLACE
# 10                    WEMBLEY GARDENS                      NaN
# 11                           SITE 4/5   COQUET ENTERPRISE PARK
# 12                               SHOP       68 EASTBOURNE ROAD
# 13                             UNIT 3              ALBERT ROAD
# 14                      3 CARR STREET                    BLYTH
# 15                       LINCOLN ROAD                NETTLEHAM
# 16               1 Church Lane, Field                      NaN
# 17                       IN WAREHOUSE                 ATLAS RD
# 18                    CHARFLEETS ROAD                      NaN
# 19                   Crackenedge Lane                 Dewsbury
# 20                 TOILETS & PREMISES                PARK ROAD
# 21                               SHOP          66 STATION ROAD
# 22                       IMPERIAL WAY                      NaN
# 23                Trough Field Supply             Delgate Bank
# 24                     Brankley House                   Plot 6
# 25        UNIT 7 CLIFFSIDE TRADE PARK           MOTHERWELL WAY
# 26      SOUTHWICK GOLD GLOVES 1ST FLR             24 THE GREEN
# 27                  5 WOODSIDE PARADE             257 WOODSIDE
# 28                185 FELIXSTOWE ROAD                  IPSWICH
# 29                  2 CORNWALLIS ROAD                      NaN
# 30   RIVERS EDGE HOTEL RIVERSIDE PARK               GREEN LANE
# 31          METER FOR UNIT 7 & UNIT 8         SOUTHCHURCH ROAD
# 32         1A MIDDLESBROUGH ROAD WEST               SOUTH BANK
# 33                                N11  Mablethorpe Chalet Park
# 34                     1-3 DEWEY ROAD                      NaN
# 35                             UNIT 5              BRINELL WAY
# 36                             Unit 7             Telford Park
# 37                                  .                        .
# 38          UNIT 5D INDUSTRIAL ESTATE           GALLAMORE LANE
# 39                     9/10 2ND METER           DEFENDER COURT
# 40                         15-17 SHOP        WEST PERCY STREET
# 41                       Haigh Street                LIVERPOOL
# 42  FACTORY INSHORE FISH & FROZEN FDS           TOD POINT ROAD
# 43                   Glassthorpe Lane                Hill Farm
# 44                       BLAKE AVENUE                      NaN
# 45                      WARWICK HOUSE      48 COLLINGWOOD ROAD
# 46                        1-2 1ST FLR          RAILWAY TERRACE
# 47                UNIT 1 LLOYDS COURT         CLEVELAND STREET
# 48                                  3             CAUTLEY ROAD
# 49        BALFOUR BEATTY RAIL OFFICES            FELIXSTOWE RD
# 50              DUNE, EAST FARM HOUSE                 EMBLETON
# 51                             UNIT 2           LUSTRUM AVENUE
# 52                  41 GASKELL AVENUE            SOUTH SHIELDS
# 53                         9 Scossels                Glemsford
# 54                  66 SHOP - UNIT 11            HUDSON STREET
# 55                               SHOP           1B MAIN STREET
# 56  TAP SUPPLY - ST NICHOLAS CEMETERY           NUNS MOOR ROAD
# 57                             Unit 2                Top Angel
# 58                      OFFICE R/O 71              HIGH STREET
# 59                  FINNINGLEY QUARRY               CROFT ROAD
#
#                    Address_Line_3         Address_Line_4 Address_Line_5  \
# 0                      MAIDENHEAD              BERKSHIRE            NaN
# 1                      DARLINGTON                    NaN            NaN
# 2   TELFORD WAY INDUSTRIAL ESTATE              KETTERING       NN16 8PX
# 3                         NN5 6NT                    NaN            NaN
# 4                          MURTON                 SEAHAM            NaN
# 5                  NEEDHAM MARKET                IPSWICH        IP6 8NZ
# 6                         IPSWICH                IP2 8HD            NaN
# 7                             NaN                    NaN      CAMBRIDGE
# 8                        WICKFORD                    NaN            NaN
# 9                      DARLINGTON                    NaN            NaN
# 10                        CAMBOIS                  BLYTH            NaN
# 11                          AMBLE                MORPETH            NaN
# 12                  MIDDLESBROUGH                    NaN            NaN
# 13                        RUSHDEN               NN10 0BU            NaN
# 14                            NaN                    NaN            NaN
# 15                        LINCOLN                LN2 2NE            NaN
# 16                            NaN                    NaN            NaN
# 17                            NaN                 LONDON            NaN
# 18                            NaN          CANVEY ISLAND            NaN
# 19                West Yorkshire                     NaN            NaN
# 20                      ASHINGTON                    NaN            NaN
# 21                      UPMINSTER                    NaN            NaN
# 22                        WATFORD          HERTFORDHSIRE            NaN
# 23                   Weston Hills               SPALDING            NaN
# 24                        Far End        Boothby Graffoe        LINCOLN
# 25                          GRAYS                    NaN            NaN
# 26                      SOUTHWICK             SUNDERLAND            NaN
# 27                   LEIGH ON SEA                    NaN            NaN
# 28                        IP3 9BJ                    NaN            NaN
# 29                            NaN                    NaN        LINCOLN
# 30                   FRIARS GOOSE              GATESHEAD            NaN
# 31                              .        SOUTHEND ON SEA              .
# 32                  MIDDLESBROUGH                    NaN            NaN
# 33                   Links Avenue            MABLETHORPE            NaN
# 34                            NaN               DAGENHAM            NaN
# 35                 GREAT YARMOUTH                    NaN            NaN
# 36                  Telford Road,  Clacton on Sea, Essex            NaN
# 37                 2 HAMPDEN ROAD                      .        HITCHIN
# 38                   MARKET RASEN                LN8 3HZ            NaN
# 39                     SUNDERLAND                    NaN            NaN
# 40                  NORTH SHIELDS                    NaN            NaN
# 41                            NaN                    NaN            NaN
# 42                         REDCAR                    NaN            NaN
# 43                         Trough                Harpole    NORTHAMPTON
# 44                        BARKING               DAGENHAM            NaN
# 45                         WITHAM                    NaN            NaN
# 46                     SUNDERLAND                    NaN            NaN
# 47                     DARLINGTON                    NaN            NaN
# 48                            NaN                    NaN      SOUTHWOLD
# 49                            NaN                 LONDON            NaN
# 50                        ALNWICK                    NaN            NaN
# 51               STOCKTON ON TEES                    NaN            NaN
# 52                            NaN                    NaN            NaN
# 53                        SUDBURY                    NaN            NaN
# 54                  NORTH SHIELDS                    NaN            NaN
# 55                      CRAWCROOK                  RYTON            NaN
# 56            NEWCASTLE UPON TYNE                    NaN            NaN
# 57   Buckingham Industrial Estate             BUCKINGHAM       MK18 1TH
# 58                  CANVEY ISLAND                    NaN            NaN
# 59                     FINNINGLEY              DONCASTER            NaN
#
#     Postcode Street_In_Postcode
# 0    SL6 8LT                 No
# 1    DL3 0RX                Yes
# 2   NN16 8PX                Yes
# 3    NN5 6NT                Yes
# 4    SR7 9HU                Yes
# 5    IP6 8NZ                Yes
# 6    IP2 8HD                Yes
# 7    CB2 1AB                Yes
# 8   SS11 8AW                Yes
# 9    DL3 6LP                Yes
# 10  NE24 1RZ                Yes
# 11  NE65 0PE                Yes
# 12   TS5 6QL                Yes
# 13  NN10 0BU                Yes
# 14  NE24 4NG                Yes
# 15   LN2 2NE                Yes
# 16   CO3 8PB                Yes
# 17  NW10 6DD                Yes
# 18   SS8 0SG                Yes
# 19  WF13 1PT                Yes
# 20  NE63 9NF                Yes
# 21  RM14 2TD                Yes
# 22  WD24 4LQ                Yes
# 23  PE12 6DW                Yes
# 24   LN5 0LG                Yes
# 25  RM20 3XD                Yes
# 26   SR5 2JE                Yes
# 27   SS9 4SS                Yes
# 28   IP3 9BJ                Yes
# 29   LN3 4PD                Yes
# 30  NE10 0SB                Yes
# 31   SS1 2PE                Yes
# 32   TS6 6NS                Yes
# 33  LN12 1QN                Yes
# 34  RM10 8AR                Yes
# 35  NR31 0LU                Yes
# 36  CO15 4LP                Yes
# 37   SG4 0LD                Yes
# 38   LN8 3HZ                Yes
# 39   SR5 3PE                Yes
# 40  NE29 0AH                Yes
# 41    L3 8NP                Yes
# 42  TS10 5BE                Yes
# 43   NN7 4DU                Yes
# 44  IG11 9RT                Yes
# 45   CM8 2DZ                Yes
# 46   SR4 0PA                Yes
# 47   DL1 2PB                Yes
# 48  IP18 6DD                Yes
# 49   SE2 9RN                Yes
# 50  NE66 3XB                Yes
# 51  TS18 2RB                Yes
# 52  NE34 9TQ                Yes
# 53  CO10 7UR                Yes
# 54  NE30 1DL                Yes
# 55  NE40 4TX                Yes
# 56   NE4 9AU                Yes
# 57  MK18 1TH                Yes
# 58   SS8 7RD                Yes
# 59   DN9 3DW                Yes

# %%
input_data.loc[input_data['Postcode'] == 'SL6 8LT']
# Out:
#   Address_Line_1         Address_Line_2 Address_Line_3 Address_Line_4  \
# 0         UNIT 3  39-41 MOORBRIDGE ROAD     MAIDENHEAD      BERKSHIRE
#
#   Address_Line_5 Postcode Match
# 0            NaN  SL6 8LT    No

# %%
abp_data.loc[abp_data['POSTCODE'] == 'SL6 8LT']
# Out:
# Empty DataFrame
# Columns: [SINGLE_LINE_ADDRESS, POSTCODE, STREET_NAME]
# Index: []
